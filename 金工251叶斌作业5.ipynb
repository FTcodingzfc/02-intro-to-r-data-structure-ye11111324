# %% [markdown]
# 1. 将posts和replys数据集导入R中，命名为r.posts和r.replys，保留所有字段名，所有字段空⽩转化
# 为NA。

# %%
library(data.table)
library(stringr)

r.posts <- fread("posts.csv", na.strings = c("", "NA"))
r.replys <- fread("replys.csv", na.strings = c("", "NA"))
# Out:
# Error in fread("posts.csv", na.strings = c("", "NA")): File 'posts.csv' does not exist or is non-readable. getwd()=='d:/vs/Microsoft VS Code'
# Traceback:
#
# 1. stopf("File '%s' does not exist or is non-readable. getwd()=='%s'",
#  .     file, getwd())
# 2. raise_condition(stop, gettextf(fmt, ..., domain = domain), c(class,
#  .     "simpleError", "error", "condition"))
# 3. signal(obj)
